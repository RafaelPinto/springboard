# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            302 non-null    datetime64[ns]
#  1   City of London        303 non-null    object
#  2   Barking & Dagenham    303 non-null    object
#  3   Barnet                303 non-null    object
#  4   Bexley                303 non-null    object
#  5   Brent                 303 non-null    object
#  6   Bromley               303 non-null    object
#  7   Camden                303 non-null    object
#  8   Croydon               303 non-null    object
#  9   Ealing                303 non-null    object
#  10  Enfield               303 non-null    object
#  11  Greenwich             303 non-null    object
#  12  Hackney               303 non-null    object
#  13  Hammersmith & Fulham  303 non-null    object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()

# %%
properties
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000001                91449              82202.8
# Barking & Dagenham    E09000002              50460.2              51085.8
# Barnet                E09000003              93284.5              93190.2
# Bexley                E09000004              64958.1              64787.9
# Brent                 E09000005              71306.6              72022.3
# Bromley               E09000006              81671.5              81657.6
# Camden                E09000007               120933               119509
# Croydon               E09000008              69158.2              68951.1
# Ealing                E09000009              79885.9              80897.1
# Enfield               E09000010              72514.7              73155.2
# Greenwich             E09000011              62300.1              60993.3
# ...

# %%
properties.reset_index(inplace=True)

# %%
properties.columns = properties.iloc[0, :]

# %%
properties= properties.iloc[1:, :].copy()

# %%
properties
# Out:
# 0             Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001               91449             82202.8
# 2     Barking & Dagenham  E09000002             50460.2             51085.8
# 3                 Barnet  E09000003             93284.5             93190.2
# 4                 Bexley  E09000004             64958.1             64787.9
# 5                  Brent  E09000005             71306.6             72022.3
# 6                Bromley  E09000006             81671.5             81657.6
# 7                 Camden  E09000007              120933              119509
# 8                Croydon  E09000008             69158.2             68951.1
# 9                 Ealing  E09000009             79885.9             80897.1
# 10               Enfield  E09000010             72514.7             73155.2
# 11             Greenwich  E09000011             62300.1             60993.3
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties.rename(columns={'Unnamed: 0': 'London_Borough', pd.NaT: 'Area_Code' }, inplace=True)

# %%
for col in properties.columns:
    print(col)
# Out:
# London_Borough
# Area_Code
# 1995-01-01 00:00:00
# 1995-02-01 00:00:00
# 1995-03-01 00:00:00
# 1995-04-01 00:00:00
# 1995-05-01 00:00:00
# 1995-06-01 00:00:00
# 1995-07-01 00:00:00
# 1995-08-01 00:00:00
# 1995-09-01 00:00:00
# 1995-10-01 00:00:00
# 1995-11-01 00:00:00
# 1995-12-01 00:00:00
# 1996-01-01 00:00:00
# 1996-02-01 00:00:00
# 1996-03-01 00:00:00
# 1996-04-01 00:00:00
# 1996-05-01 00:00:00
# 1996-06-01 00:00:00
# 1996-07-01 00:00:00
# 1996-08-01 00:00:00
# 1996-09-01 00:00:00
# 1996-10-01 00:00:00
# 1996-11-01 00:00:00
# 1996-12-01 00:00:00
# 1997-01-01 00:00:00
# 1997-02-01 00:00:00
# 1997-03-01 00:00:00
# 1997-04-01 00:00:00
# 1997-05-01 00:00:00
# 1997-06-01 00:00:00
# 1997-07-01 00:00:00
# 1997-08-01 00:00:00
# 1997-09-01 00:00:00
# 1997-10-01 00:00:00
# 1997-11-01 00:00:00
# 1997-12-01 00:00:00
# 1998-01-01 00:00:00
# 1998-02-01 00:00:00
# 1998-03-01 00:00:00
# 1998-04-01 00:00:00
# 1998-05-01 00:00:00
# 1998-06-01 00:00:00
# 1998-07-01 00:00:00
# 1998-08-01 00:00:00
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
_, _, *time_cols = properties.columns

# %%
time_cols
# Out:
# [Timestamp('1995-01-01 00:00:00'),
#  Timestamp('1995-02-01 00:00:00'),
#  Timestamp('1995-03-01 00:00:00'),
#  Timestamp('1995-04-01 00:00:00'),
#  Timestamp('1995-05-01 00:00:00'),
#  Timestamp('1995-06-01 00:00:00'),
#  Timestamp('1995-07-01 00:00:00'),
#  Timestamp('1995-08-01 00:00:00'),
#  Timestamp('1995-09-01 00:00:00'),
#  Timestamp('1995-10-01 00:00:00'),
#  Timestamp('1995-11-01 00:00:00'),
#  Timestamp('1995-12-01 00:00:00'),
#  Timestamp('1996-01-01 00:00:00'),
#  Timestamp('1996-02-01 00:00:00'),
#  Timestamp('1996-03-01 00:00:00'),
#  Timestamp('1996-04-01 00:00:00'),
#  Timestamp('1996-05-01 00:00:00'),
#  Timestamp('1996-06-01 00:00:00'),
#  Timestamp('1996-07-01 00:00:00'),
#  Timestamp('1996-08-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-10-01 00:00:00'),
#  Timestamp('1996-11-01 00:00:00'),
#  Timestamp('1996-12-01 00:00:00'),
#  Timestamp('1997-01-01 00:00:00'),
#  Timestamp('1997-02-01 00:00:00'),
#  Timestamp('1997-03-01 00:00:00'),
# ...

# %%
melted = pd.melt(properties,
                 id_vars=['London_Borough', 'Area_Code'],
                 value_vars=time_cols,
                 var_name='Month',
                 value_name='Average_Price')

# %%
melted
# Out:
#            London_Borough  Area_Code      Month Average_Price
# 0          City of London  E09000001 1995-01-01         91449
# 1      Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2                  Barnet  E09000003 1995-01-01       93284.5
# 3                  Bexley  E09000004 1995-01-01       64958.1
# 4                   Brent  E09000005 1995-01-01       71306.6
# ...                   ...        ...        ...           ...
# 14491              LONDON  E12000007 2020-02-01        476972
# 14492          SOUTH EAST  E12000008 2020-02-01        321329
# 14493          SOUTH WEST  E12000009 2020-02-01        258044
# 14494         Unnamed: 47        NaN 2020-02-01           NaN
# 14495             England  E92000001 2020-02-01        246341
#
# [14496 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14496 entries, 0 to 14495
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  14496 non-null  object
#  1   Area_Code       13590 non-null  object
#  2   Month           14496 non-null  datetime64[ns]
#  3   Average_Price   13590 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 453.1+ KB

# %%
melted['Average_Price'] = pd.to_numeric(melted['Average_Price'])

# %%
melted['London_Borough'] = melted['London_Borough'].astype('string')
melted['Area_Code'] = melted['Area_Code'].astype('string')

# %%
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14496 entries, 0 to 14495
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  14496 non-null  string
#  1   Area_Code       13590 non-null  string
#  2   Month           14496 non-null  datetime64[ns]
#  3   Average_Price   13590 non-null  float64
# dtypes: datetime64[ns](1), float64(1), string(2)
# memory usage: 453.1 KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
melted.dropna(subset=['Area_Code'], inplace=True)

# %%
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13590 entries, 0 to 14495
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  13590 non-null  string
#  1   Area_Code       13590 non-null  string
#  2   Month           13590 non-null  datetime64[ns]
#  3   Average_Price   13590 non-null  float64
# dtypes: datetime64[ns](1), float64(1), string(2)
# memory usage: 530.9 KB

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
city_london = melted.loc[melted.London_Borough == 'City of London', :]

# %%
city_london.plot(x='Month',
                 y='Average_Price',
                 figsize=(10,5))
plt.title('City of London average house price over the last two decades')
plt.xlabel('Time')
plt.ylabel('Average house price [£]')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# I think simpler just to take the percent change cumulative sum over the monthly average prices
melted['avg_price_pct_change'] = melted.groupby('London_Borough')['Average_Price'].pct_change() * 100
melted['avg_price_pct_change_cumsum'] = melted.groupby('London_Borough')['avg_price_pct_change'].cumsum()

# %%
melted
# Out:
#            London_Borough  Area_Code      Month  Average_Price  \
# 0          City of London  E09000001 1995-01-01    91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                  Barnet  E09000003 1995-01-01    93284.51832
# 3                  Bexley  E09000004 1995-01-01    64958.09036
# 4                   Brent  E09000005 1995-01-01    71306.56698
# ...                   ...        ...        ...            ...
# 14490     EAST OF ENGLAND  E12000006 2020-02-01   286869.06350
# 14491              LONDON  E12000007 2020-02-01   476972.07330
# 14492          SOUTH EAST  E12000008 2020-02-01   321329.36450
# 14493          SOUTH WEST  E12000009 2020-02-01   258043.97170
# 14495             England  E92000001 2020-02-01   246341.31270
#
#        avg_price_pct_change  avg_price_pct_change_cumsum
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# ...

# %%
melted_city_london = melted.loc[melted['London_Borough']=='City of London']
melted_city_london
# Out:
#        London_Borough  Area_Code      Month  Average_Price  \
# 0      City of London  E09000001 1995-01-01    91448.98487
# 48     City of London  E09000001 1995-02-01    82202.77314
# 96     City of London  E09000001 1995-03-01    79120.70256
# 144    City of London  E09000001 1995-04-01    77101.20804
# 192    City of London  E09000001 1995-05-01    84409.14932
# ...               ...        ...        ...            ...
# 14256  City of London  E09000001 2019-10-01   827374.83320
# 14304  City of London  E09000001 2019-11-01   778869.83140
# 14352  City of London  E09000001 2019-12-01   739644.70060
# 14400  City of London  E09000001 2020-01-01   748456.81770
# 14448  City of London  E09000001 2020-02-01   730282.10540
#
#        avg_price_pct_change  avg_price_pct_change_cumsum
# 0                       NaN                          NaN
# 48               -10.110787                   -10.110787
# 96                -3.749351                   -13.860138
# ...

# %%
melted_city_london.plot(x='Month',
                        y='avg_price_pct_change_cumsum',
                        figsize=(10,5))
plt.title('Monthly average house price percent change cumulative sum for the City of London')
plt.xlabel('Time')
plt.ylabel('avg_price_pct_change_cumsum [%]')
plt.show()

# %%
# Let's aggregate the cumulative percent change by year's Last to reduce the number of points to plot
resampled = melted.loc[:, ['London_Borough', 'Month', 'avg_price_pct_change_cumsum']]

# %%
resampled.set_index('Month', inplace=True)

# %%
resampled
# Out:
#                 London_Borough  avg_price_pct_change_cumsum
# Month
# 1995-01-01      City of London                          NaN
# 1995-01-01  Barking & Dagenham                          NaN
# 1995-01-01              Barnet                          NaN
# 1995-01-01              Bexley                          NaN
# 1995-01-01               Brent                          NaN
# ...                        ...                          ...
# 2020-02-01     EAST OF ENGLAND                   164.259642
# 2020-02-01              LONDON                   188.568911
# 2020-02-01          SOUTH EAST                   163.253961
# 2020-02-01          SOUTH WEST                   157.259942
# 2020-02-01             England                   154.914142
#
# [13590 rows x 2 columns]

# %%
resampled = resampled.groupby('London_Borough').resample('A').agg('last')

# %%
resampled
# Out:
#                                    London_Borough  avg_price_pct_change_cumsum
# London_Borough     Month
# Barking & Dagenham 1995-12-31  Barking & Dagenham                     1.101244
#                    1996-12-31  Barking & Dagenham                     6.757361
#                    1997-12-31  Barking & Dagenham                    14.281068
#                    1998-12-31  Barking & Dagenham                    23.363089
#                    1999-12-31  Barking & Dagenham                    31.491060
# ...                                           ...                          ...
# YORKS & THE HUMBER 2016-12-31  YORKS & THE HUMBER                   125.212128
#                    2017-12-31  YORKS & THE HUMBER                   129.061895
#                    2018-12-31  YORKS & THE HUMBER                   131.499536
#                    2019-12-31  YORKS & THE HUMBER                   133.822545
#                    2020-12-31  YORKS & THE HUMBER                   131.593755
# ...

# %%
resampled = resampled.droplevel(0, axis=0)

# %%
resampled
# Out:
#                 London_Borough  avg_price_pct_change_cumsum
# Month
# 1995-12-31  Barking & Dagenham                     1.101244
# 1996-12-31  Barking & Dagenham                     6.757361
# 1997-12-31  Barking & Dagenham                    14.281068
# 1998-12-31  Barking & Dagenham                    23.363089
# 1999-12-31  Barking & Dagenham                    31.491060
# ...                        ...                          ...
# 2016-12-31  YORKS & THE HUMBER                   125.212128
# 2017-12-31  YORKS & THE HUMBER                   129.061895
# 2018-12-31  YORKS & THE HUMBER                   131.499536
# 2019-12-31  YORKS & THE HUMBER                   133.822545
# 2020-12-31  YORKS & THE HUMBER                   131.593755
#
# [1170 rows x 2 columns]

# %%
pivoted = pd.pivot_table(resampled, values='avg_price_pct_change_cumsum', index='Month', columns='London_Borough')

# %%
pivoted
# Out:
# London_Borough  Barking & Dagenham      Barnet      Bexley       Brent  \
# Month
# 1995-12-31                1.101244   -2.271715   -1.752736    1.723813
# 1996-12-31                6.757361    4.263320    2.365676    9.432955
# 1997-12-31               14.281068   21.730515   13.994952   28.011686
# 1998-12-31               23.363089   30.277119   25.050205   38.528641
# 1999-12-31               31.491060   47.756454   37.185163   55.492222
# 2000-12-31               48.892584   63.844534   52.290138   74.251756
# 2001-12-31               65.886184   77.524101   63.952270   85.348824
# 2002-12-31               97.210123   94.086936   86.970710  108.167230
# 2003-12-31              110.178864  103.729162   97.033695  115.678798
# 2004-12-31              119.443509  111.645797  105.287079  122.963683
# 2005-12-31              118.584519  111.805911  106.801137  125.712633
# 2006-12-31              125.554911  119.509407  113.027033  132.483631
# ...

# %%
pivoted.plot(figsize=(12,12))
plt.title('Monthly average house price percent change cumulative sum for London boroughs')
plt.xlabel('Time')
plt.ylabel('avg_price_pct_change_cumsum [%]')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Now what would that top pink line be?
# Let's sort by the 2018 value

# Grab and sort the last row of the pivoted table
sorted_boroughs = pivoted.loc['2018-12-31', :].sort_values(ascending=False)

# %%
sorted_boroughs
# Out:
# London_Borough
# City of London          290.834666
# Hackney                 226.208312
# Kensington & Chelsea    212.960265
# Lambeth                 207.518579
# Southwark               206.966117
# Westminster             205.580527
# Camden                  205.500981
# Tower Hamlets           205.444612
# Inner London            201.333119
# Haringey                201.298030
# Waltham Forest          199.861874
# Islington               196.652258
# Wandsworth              195.116025
# Lewisham                194.487201
# Brent                   193.437505
# Newham                  192.390617
# Merton                  188.224484
# LONDON                  187.732224
# Greenwich               185.591328
# Hammersmith & Fulham    183.127096
# Kingston upon Thames    182.652451
# Ealing                  182.551561
# Richmond upon Thames    182.159634
# Barking & Dagenham      181.492284
# Redbridge               180.341101
# Outer London            178.283055
# ...

# %%
print('The top five boroughs with greatest house price increase, on average, over the past two decades are:')
print(sorted_boroughs[:5])

print('\n')
print('The bottom five boroughs with greatest house price increase, on average, over the past two decades are:')
print(sorted_boroughs[:-6:-1])
# Out:
# The top five boroughs with greatest house price increase, on average, over the past two decades are:
# London_Borough
# City of London          290.834666
# Hackney                 226.208312
# Kensington & Chelsea    212.960265
# Lambeth                 207.518579
# Southwark               206.966117
# Name: 2018-12-31 00:00:00, dtype: float64
#
#
# The bottom five boroughs with greatest house price increase, on average, over the past two decades are:
# London_Borough
# NORTH EAST            116.963093
# YORKS & THE HUMBER    131.499536
# NORTH WEST            133.854810
# WEST MIDLANDS         136.242533
# EAST MIDLANDS         146.202099
# Name: 2018-12-31 00:00:00, dtype: float64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(group):
    """
    Return ratio of house price from years 2018 and 1998.
    """
    avg_price_1998 = group[group.Month.dt.year == 1998].Average_Price.mean()
    avg_price_2018 = group[group.Month.dt.year == 2018].Average_Price.mean()
    
    return avg_price_1998 / avg_price_2018

# %%
price_ratios = melted.groupby('London_Borough').apply(create_price_ratio)
price_ratios.name = 'Ratio of house price from years 2018 and 1998'

# %%
sorted_price_ratios = price_ratios.sort_values()
sorted_price_ratios
# Out:
# London_Borough
# Hackney                 0.161335
# Waltham Forest          0.171387
# Southwark               0.181275
# Lewisham                0.183512
# Westminster             0.186791
# Newham                  0.188488
# City of London          0.188622
# Inner London            0.193392
# Haringey                0.194756
# Kensington & Chelsea    0.196755
# Lambeth                 0.201704
# Camden                  0.202620
# Barking & Dagenham      0.204223
# Brent                   0.204309
# Islington               0.206439
# Greenwich               0.209950
# Wandsworth              0.210185
# Merton                  0.210914
# LONDON                  0.213685
# Tower Hamlets           0.216137
# Redbridge               0.223655
# Outer London            0.226298
# Barnet                  0.229453
# Havering                0.231202
# Ealing                  0.231940
# Kingston upon Thames    0.234162
# Enfield                 0.234551
# Bexley                  0.235351
# ...

# %%
print('The top five London Borouhgs based on 1998/2018 house price ratio are')
print(sorted_price_ratios[:5])
print('Smaller ratio means more appreciation of the borough')
# Out:
# The top five London Borouhgs based on 1998/2018 house price ratio are
# London_Borough
# Hackney           0.161335
# Waltham Forest    0.171387
# Southwark         0.181275
# Lewisham          0.183512
# Westminster       0.186791
# Name: Ratio of house price from years 2018 and 1998, dtype: float64
# Smaller ratio means more appreciation of the borough

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Based on the **Monthly average house price percent change cumulative sum for London boroughs** the top five boroughs in London are:
#
# | London Borough          |  avg_price_pct_change_cumsum (%) |
# | ----------------------- | ---------- |
# | City of London          | 290.84 |
# | Hackney                 | 226.21 |
# | Kensington & Chelsea    | 212.96 |
# | Lambeth                 | 207.52 |
# | Southwark               | 206.97 |
#
# The table above shows that the house appreciation in the top five boroughs is between 200% and 290% from 1995 to 2018.
#
# On the other hand, when using the **Ratio of house price from years 2018 and 1998** the top five boroughs list is different:
#
# | London Borough    | 1998 / 2018 price |
# | ----------------------- | ---------- |
# | Hackney           | 0.16 |
# | Waltham Forest    | 0.17 |
# | Southwark         | 0.18 |
# | Lewisham          | 0.18 |
# | Westminster       | 0.19 |
#
# Where boroughs Hackney and Southwark persist, but the other three are different.
#
# I think the main driver for this difference is the aggregation method used in each case. In the first case I used the cumulative sum of the monthly percent change in average house price. This incrementally adds or subtracts the monthly percent change, and thus takes into account these (monthly) high frequency fluctuations. Given the cumulative nature of this metric, to downsample I only had to take the accumulated value in December of each year.
#
# Conversely, the second method (ratios) only looks at the mean house price for a given pair of years (1998 and 2018) and then divides the two, which gives a good quick estimation but discounts the events of the real state market for the years in between, so it can't yield a yearly appreciation curve.
